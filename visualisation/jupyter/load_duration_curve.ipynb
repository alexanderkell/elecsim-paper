# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as plticker
import matplotlib.ticker as ticker

# %%
segment_demand_diff = [17568, 21964, 23127, 24327, 25520, 26760, 27888, 28935, 29865, 30721, 31567, 32315, 33188, 34182, 35505, 37480, 39585, 42206, 45209, 52152]
segment_time = [8752.5, 8291.83, 7831.17, 7370.5, 6909.92, 6449.25, 5988.58, 5527.92, 5067.25, 4606.58, 4146, 3685.33, 3224.67, 2764, 2303.33, 1842.67, 1382.08, 921.42, 460.75, 0.08]

# %%
ldc = pd.DataFrame({"segment_demand_diff":[17568, 21964, 23127, 24327, 25520, 26760, 27888, 28935, 29865, 30721, 31567, 32315, 33188, 34182, 35505, 37480, 39585, 42206, 45209, 52152],"segment_time" : [8752.5, 8291.83, 7831.17, 7370.5, 6909.92, 6449.25, 5988.58, 5527.92, 5067.25, 4606.58, 4146, 3685.33, 3224.67, 2764, 2303.33, 1842.67, 1382.08, 921.42, 460.75, 0.08]
})
ldc['percent_time'] = pd.to_numeric(round((ldc["segment_time"]/8752.5)*100,0))
ldc
# Out:
#     segment_demand_diff  segment_time  percent_time
# 0                 17568       8752.50         100.0
# 1                 21964       8291.83          95.0
# 2                 23127       7831.17          89.0
# 3                 24327       7370.50          84.0
# 4                 25520       6909.92          79.0
# 5                 26760       6449.25          74.0
# 6                 27888       5988.58          68.0
# 7                 28935       5527.92          63.0
# 8                 29865       5067.25          58.0
# 9                 30721       4606.58          53.0
# 10                31567       4146.00          47.0
# 11                32315       3685.33          42.0
# 12                33188       3224.67          37.0
# 13                34182       2764.00          32.0
# 14                35505       2303.33          26.0
# 15                37480       1842.67          21.0
# 16                39585       1382.08          16.0
# 17                42206        921.42          11.0
# 18                45209        460.75           5.0
# 19                52152          0.08           0.0

# %%
fig, ax = plt.subplots(1,1)
# sns.barplot(y=ldc.segment_demand_diff, x=ldc.segment_time, data = ldc, color='blue')
# loc = plticker.MultipleLocator(base=1.0) # this locator puts ticks at regular intervals
# ax.xaxis.set_major_locator(loc)
# plt.show()

sns.barplot(ldc.percent_time,ldc.segment_demand_diff, color="lightgreen")

plt.xaxis.set_major_locator(ticker.MultipleLocator(20))
plt.xaxis.set_major_formatter(ticker.ScalarFormatter())

plt.ylabel("Demand (MW)")
plt.xlabel("Percentage of time (%)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-8457750dee54> in <module>
#       7 sns.barplot(ldc.percent_time,ldc.segment_demand_diff, color="lightgreen")
#       8
# ----> 9 plt.xaxis.set_major_locator(ticker.MultipleLocator(20))
#      10 plt.xaxis.set_major_formatter(ticker.ScalarFormatter())
#      11
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xaxis'
